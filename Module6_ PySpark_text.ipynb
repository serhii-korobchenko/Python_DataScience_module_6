# %%
from collections import Counter

# %%
print("This is a tutorial!")
# Out:
# This is a tutorial!

# %%
ls
# Out:
# sample_data/

# %%
pwd
# Out:
# '/content'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# <a id='installing-spark'></a>
# ### Installing Spark

# %% [markdown]
# Install Dependencies:
#
#
# 1.   Java 8
# 2.   Apache Spark with hadoop and
# 3.   Findspark (used to locate the spark in the system)

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q http://archive.apache.org/dist/spark/spark-3.1.1/spark-3.1.1-bin-hadoop3.2.tgz
# !tar xf spark-3.1.1-bin-hadoop3.2.tgz
# !pip install -q findspark

# %% [markdown]
# Set Environment Variables:

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.1-bin-hadoop3.2"

# %%
# !ls
# Out:
# drive  sample_data  spark-3.1.1-bin-hadoop3.2  spark-3.1.1-bin-hadoop3.2.tgz

# %%
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled", True) # Property used to format output tables better
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://fc7cde846fae:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# <a id='exploring-the-dataset'></a>
# ## Exploring the Dataset

# %%
text_file = spark.sparkContext.textFile("/content/drive/MyDrive/data/words.txt")

# %% [markdown]
# # New Section

# %%
text_file.count()
# Out:
# 10000

# %%
counts = text_file.flatMap(lambda line: line.split(" ")).map(lambda word: (word, 1)).reduceByKey(lambda a, b: a + b)
counts.saveAsTextFile("/content/drive/MyDrive/data/results.txt")

# %%
df = counts.toDF()

# %%
df.show(50)
# Out:
# +--------------+---+
# |            _1| _2|
# +--------------+---+
# |            aa|  1|
# |           aaa|  1|
# |         aaron|  1|
# |            ab|  1|
# |           abc|  1|
# |     abilities|  1|
# |          able|  1|
# |    aboriginal|  1|
# |      abortion|  1|
# |         above|  1|
# |       abraham|  1|
# |           abs|  1|
# |        absent|  1|
# |      absolute|  1|
# |    absorption|  1|
# |      abstract|  1|
# |     abstracts|  1|
# |      academic|  1|
# |     academics|  1|
# |        accent|  1|
# |    acceptance|  1|
# |      accepted|  1|
# |     accepting|  1|
# |       accepts|  1|
# |      accessed|  1|
# | accessibility|  1|
# |    accessible|  1|
# |     accessing|  1|
# |   accessories|  1|
# |     accessory|  1|
# |     accidents|  1|
# | accommodation|  1|
# |accommodations|  1|
# |  accompanying|  1|
# |       account|  1|
# |      accounts|  1|
# | accreditation|  1|
# |      accurate|  1|
# |    accurately|  1|
# |       accused|  1|
# ...
